# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection
import geopandas as gpd
import seaborn as sns
from PIL import Image

plt.rcParams['figure.figsize'] = [18, 24]

# %%
sns.set()

# %% [markdown]
# ## Importing the data

# %%
df = pd.read_csv("uk_election_data_v2.csv")

# %%
df
# Out:
#                   Constituency                    Region      Con      Lab  \
# 0                     Aberavon                     Wales   3742.0  15416.0
# 1                    Aberconwy                     Wales  12513.0   8514.0
# 2               Aberdeen North                  Scotland   5304.0  11397.0
# 3               Aberdeen South                  Scotland  11087.0  12991.0
# 4           Airdrie and Shotts                  Scotland   3389.0  15108.0
# ..                         ...                       ...      ...      ...
# 645  Wythenshawe and Sale East        North West England  11124.0  21693.0
# 646                     Yeovil        South West England  24178.0   4053.0
# 647                   Ynys Mon                     Wales   7393.0  10871.0
# 648               York Central  Yorkshire and the Humber  13496.0  20212.0
# 649                 York Outer  Yorkshire and the Humber  26477.0  13348.0
#
#        UKIP       LD      SNP     Grn  DUP       PC  ...  WinningVotes  \
# 0    4971.0   1397.0      NaN   711.0  NaN   3663.0  ...         15416
# 1    3467.0   1391.0      NaN   727.0  NaN   3536.0  ...         12513
# 2       NaN   2050.0  24793.0     NaN  NaN      NaN  ...         24793
# 3     897.0   2252.0  20221.0   964.0  NaN      NaN  ...         20221
# 4    1088.0    678.0  23887.0     NaN  NaN      NaN  ...         23887
# ..      ...      ...      ...     ...  ...      ...  ...           ...
# 645  6354.0   1927.0      NaN  1658.0  NaN      NaN  ...         21693
# 646  7646.0  18865.0      NaN  2191.0  NaN      NaN  ...         24178
# 647  5121.0    751.0      NaN     NaN  NaN  10642.0  ...         10871
# 648  4795.0   3804.0      NaN  4791.0  NaN      NaN  ...         20212
# 649  5251.0   6269.0      NaN  2558.0  NaN      NaN  ...         26477
#
#      SecondPlaceVotes  WinningPct  Majority  MajorityPct  TurnoutPct2015  \
# 0                4971       48.90     10445        33.13            63.3
# 1                8514       39.69      3999        13.26            66.2
# 2               11397       56.43     13396        30.49            64.9
# 3               12991       41.65      7230        14.89            71.3
# 4               15108       53.94      8779        19.82            66.4
# ..                ...         ...       ...          ...             ...
# 645             11124       50.10     10569        24.43            56.9
# 646             18865       42.50      5313         9.33            69.1
# 647             10642       31.10       229         0.66            69.9
# 648             13496       42.40      6716        14.09            63.3
# 649             13348       49.10     13129        24.36            68.6
#
#      RemainPct  LeavePct LeaveMajority   2017_winner
# 0         40.1      59.9          19.8        Labour
# 1         46.7      53.3           6.6  Conservative
# 2         57.0      43.0         -14.0           SNP
# 3         67.7      32.3         -35.4  Conservative
# 4         60.0      40.0         -20.0           SNP
# ..         ...       ...           ...           ...
# 645       50.2      49.8          -0.4        Labour
# 646       40.8      59.2          18.4  Conservative
# 647       49.1      50.9           1.8        Labour
# 648       61.5      38.5         -23.0        Labour
# 649       55.1      44.9         -10.2  Conservative
#
# [650 rows x 30 columns]

# %%
# This is the constituency of the speaker of the house and, by tradition, many parties do not choose to run against...
# ... the speaker, although the are not forbidden to do so.

df[df["Constituency"] == "Buckingham"]
# Out:
#    Constituency              Region  Con  Lab     UKIP  LD  SNP     Grn  DUP  \
# 97   Buckingham  South East England  NaN  NaN  11675.0 NaN  NaN  7400.0  NaN
#
#     PC  ...  WinningVotes  SecondPlaceVotes  WinningPct  Majority  \
# 97 NaN  ...         34617             11675       64.47     22942
#
#     MajorityPct  TurnoutPct2015  RemainPct  LeavePct LeaveMajority 2017_winner
# 97        42.73             NaN       51.4      48.6          -2.8     Speaker
#
# [1 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Constituency', 'Region', 'Con', 'Lab', 'UKIP', 'LD', 'SNP', 'Grn',
#        'DUP', 'PC', 'SF', 'UUP', 'SDLP', 'Alliance', 'Ind', 'Spk', 'Others',
#        'ValidVotes', 'WinningParty', 'SecondPlace', 'WinningVotes',
#        'SecondPlaceVotes', 'WinningPct', 'Majority', 'MajorityPct',
#        'TurnoutPct2015', 'RemainPct', 'LeavePct', 'LeaveMajority',
#        '2017_winner'],
#       dtype='object')

# %%
df = df.fillna(0)

# %%
df.columns[2:17]
# Out:
# Index(['Con', 'Lab', 'UKIP', 'LD', 'SNP', 'Grn', 'DUP', 'PC', 'SF', 'UUP',
#        'SDLP', 'Alliance', 'Ind', 'Spk', 'Others'],
#       dtype='object')

# %%
df["con_ratio"] = (df["Con"] + df["UKIP"])/df.iloc[:, 2:17].sum(axis=1)

# %%
df["leave_prop"] = df["LeavePct"]/100

# %%
df
# Out:
#                   Constituency                    Region      Con      Lab  \
# 0                     Aberavon                     Wales   3742.0  15416.0
# 1                    Aberconwy                     Wales  12513.0   8514.0
# 2               Aberdeen North                  Scotland   5304.0  11397.0
# 3               Aberdeen South                  Scotland  11087.0  12991.0
# 4           Airdrie and Shotts                  Scotland   3389.0  15108.0
# ..                         ...                       ...      ...      ...
# 645  Wythenshawe and Sale East        North West England  11124.0  21693.0
# 646                     Yeovil        South West England  24178.0   4053.0
# 647                   Ynys Mon                     Wales   7393.0  10871.0
# 648               York Central  Yorkshire and the Humber  13496.0  20212.0
# 649                 York Outer  Yorkshire and the Humber  26477.0  13348.0
#
#        UKIP       LD      SNP     Grn  DUP       PC  ...  WinningPct  \
# 0    4971.0   1397.0      0.0   711.0  0.0   3663.0  ...       48.90
# 1    3467.0   1391.0      0.0   727.0  0.0   3536.0  ...       39.69
# 2       0.0   2050.0  24793.0     0.0  0.0      0.0  ...       56.43
# 3     897.0   2252.0  20221.0   964.0  0.0      0.0  ...       41.65
# 4    1088.0    678.0  23887.0     0.0  0.0      0.0  ...       53.94
# ..      ...      ...      ...     ...  ...      ...  ...         ...
# 645  6354.0   1927.0      0.0  1658.0  0.0      0.0  ...       50.10
# 646  7646.0  18865.0      0.0  2191.0  0.0      0.0  ...       42.50
# 647  5121.0    751.0      0.0     0.0  0.0  10642.0  ...       31.10
# 648  4795.0   3804.0      0.0  4791.0  0.0      0.0  ...       42.40
# 649  5251.0   6269.0      0.0  2558.0  0.0      0.0  ...       49.10
#
#      Majority  MajorityPct  TurnoutPct2015  RemainPct  LeavePct  \
# 0       10445        33.13            63.3       40.1      59.9
# 1        3999        13.26            66.2       46.7      53.3
# 2       13396        30.49            64.9       57.0      43.0
# 3        7230        14.89            71.3       67.7      32.3
# 4        8779        19.82            66.4       60.0      40.0
# ..        ...          ...             ...        ...       ...
# 645     10569        24.43            56.9       50.2      49.8
# 646      5313         9.33            69.1       40.8      59.2
# 647       229         0.66            69.9       49.1      50.9
# 648      6716        14.09            63.3       61.5      38.5
# 649     13129        24.36            68.6       55.1      44.9
#
#      LeaveMajority   2017_winner con_ratio leave_prop
# 0             19.8        Labour  0.276401      0.599
# 1              6.6  Conservative  0.530052      0.533
# 2            -14.0           SNP  0.120721      0.430
# 3            -35.4  Conservative  0.246833      0.323
# 4            -20.0           SNP  0.101093      0.400
# ..             ...           ...       ...        ...
# 645           -0.4        Labour  0.403994      0.498
# 646           18.4  Conservative  0.558973      0.592
# 647            1.8        Labour  0.358300      0.509
# 648          -23.0        Labour  0.383644      0.385
# 649          -10.2  Conservative  0.588613      0.449
#
# [650 rows x 32 columns]

# %%
plt.plot(df["con_ratio"], df["leave_prop"], "+")
slope, intercept = np.polyfit(df["con_ratio"], df["leave_prop"], 1)
xx = np.linspace(0, 1)
plt.plot(xx, intercept+xx*slope)
plt.title("Scatterplot showing the relationship between Leave support and Tory or UKIP support", fontsize=24)
plt.xlabel("Ratio of Con/UKIP voters", fontsize=20)
plt.ylabel("Proportion of voters who voted leave", fontsize=20)
plt.savefig('politics_scatterplot.jpg', format='jpg', dpi=400, bbox_inches='tight')

# %%
df["con_ratio"].corr(df["leave_prop"])
# Out:
# 0.4959820006260413

# %%
df["prod_var"] = df["con_ratio"] * (df["leave_prop"])

# %%
df
# Out:
#                   Constituency                    Region      Con      Lab  \
# 0                     Aberavon                     Wales   3742.0  15416.0
# 1                    Aberconwy                     Wales  12513.0   8514.0
# 2               Aberdeen North                  Scotland   5304.0  11397.0
# 3               Aberdeen South                  Scotland  11087.0  12991.0
# 4           Airdrie and Shotts                  Scotland   3389.0  15108.0
# ..                         ...                       ...      ...      ...
# 645  Wythenshawe and Sale East        North West England  11124.0  21693.0
# 646                     Yeovil        South West England  24178.0   4053.0
# 647                   Ynys Mon                     Wales   7393.0  10871.0
# 648               York Central  Yorkshire and the Humber  13496.0  20212.0
# 649                 York Outer  Yorkshire and the Humber  26477.0  13348.0
#
#        UKIP       LD      SNP     Grn  DUP       PC  ...  Majority  \
# 0    4971.0   1397.0      0.0   711.0  0.0   3663.0  ...     10445
# 1    3467.0   1391.0      0.0   727.0  0.0   3536.0  ...      3999
# 2       0.0   2050.0  24793.0     0.0  0.0      0.0  ...     13396
# 3     897.0   2252.0  20221.0   964.0  0.0      0.0  ...      7230
# 4    1088.0    678.0  23887.0     0.0  0.0      0.0  ...      8779
# ..      ...      ...      ...     ...  ...      ...  ...       ...
# 645  6354.0   1927.0      0.0  1658.0  0.0      0.0  ...     10569
# 646  7646.0  18865.0      0.0  2191.0  0.0      0.0  ...      5313
# 647  5121.0    751.0      0.0     0.0  0.0  10642.0  ...       229
# 648  4795.0   3804.0      0.0  4791.0  0.0      0.0  ...      6716
# 649  5251.0   6269.0      0.0  2558.0  0.0      0.0  ...     13129
#
#      MajorityPct  TurnoutPct2015  RemainPct  LeavePct  LeaveMajority  \
# 0          33.13            63.3       40.1      59.9           19.8
# 1          13.26            66.2       46.7      53.3            6.6
# 2          30.49            64.9       57.0      43.0          -14.0
# 3          14.89            71.3       67.7      32.3          -35.4
# 4          19.82            66.4       60.0      40.0          -20.0
# ..           ...             ...        ...       ...            ...
# 645        24.43            56.9       50.2      49.8           -0.4
# 646         9.33            69.1       40.8      59.2           18.4
# 647         0.66            69.9       49.1      50.9            1.8
# 648        14.09            63.3       61.5      38.5          -23.0
# 649        24.36            68.6       55.1      44.9          -10.2
#
#       2017_winner  con_ratio leave_prop  prod_var
# 0          Labour   0.276401      0.599  0.165564
# 1    Conservative   0.530052      0.533  0.282518
# 2             SNP   0.120721      0.430  0.051910
# 3    Conservative   0.246833      0.323  0.079727
# 4             SNP   0.101093      0.400  0.040437
# ..            ...        ...        ...       ...
# 645        Labour   0.403994      0.498  0.201189
# 646  Conservative   0.558973      0.592  0.330912
# 647        Labour   0.358300      0.509  0.182375
# 648        Labour   0.383644      0.385  0.147703
# 649  Conservative   0.588613      0.449  0.264287
#
# [650 rows x 33 columns]

# %%
df.describe()
# Out:
#                 Con           Lab          UKIP            LD           SNP  \
# count    650.000000    650.000000    650.000000    650.000000    650.000000
# mean   17384.567692  14380.467692   5970.921538   3716.710769   2237.593846
# std     9405.794586   7411.664181   3068.353598   4238.213782   7243.263179
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     8808.000000   8447.750000   4050.250000   1309.000000      0.000000
# 50%    17856.000000  14350.000000   6289.000000   2120.500000      0.000000
# 75%    25384.750000  19279.000000   7864.500000   4197.500000      0.000000
# max    36607.000000  40563.000000  19642.000000  25194.000000  34831.000000
#
#                 Grn           DUP            PC            SF           UUP  \
# count    650.000000    650.000000    650.000000    650.000000    650.000000
# mean    1780.943077    283.476923    279.544615    271.126154    176.823077
# std     1602.188194   2000.244194   1371.160216   2037.219340   1459.175983
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1032.500000      0.000000      0.000000      0.000000      0.000000
# 50%     1522.500000      0.000000      0.000000      0.000000      0.000000
# 75%     2256.500000      0.000000      0.000000      0.000000      0.000000
# max    22871.000000  19575.000000  15140.000000  23078.000000  23608.000000
#
#        ...  WinningPct      Majority  MajorityPct  TurnoutPct2015   RemainPct  \
# count  ...  650.000000    650.000000   650.000000      650.000000  650.000000
# mean   ...   49.787662  11478.930769    24.073123       53.084015   48.190154
# std    ...    7.609409   7090.955203    13.955863       26.933850   11.486188
# min    ...   24.500000     27.000000     0.060000        0.000000   25.100000
# 25%    ...   43.825000   5610.750000    12.732500       56.300000   40.025000
# 50%    ...   49.640000  10821.500000    24.265000       64.900000   46.400000
# 75%    ...   54.700000  16705.250000    33.970000       69.900000   54.850000
# max    ...   81.300000  34655.000000    72.330000       81.910000   79.500000
#
#          LeavePct  LeaveMajority   con_ratio  leave_prop    prod_var
# count  650.000000     650.000000  650.000000  650.000000  650.000000
# mean    51.818769       3.628615    0.484445    0.518188    0.262460
# std     11.484459      22.970014    0.200912    0.114845    0.130494
# min     20.500000     -59.000000    0.000000    0.205000    0.000000
# 25%     45.150000      -9.700000    0.347498    0.451500    0.169340
# 50%     53.600000       7.200000    0.519794    0.536000    0.282857
# 75%     59.975000      19.950000    0.658066    0.599750    0.362121
# max     74.900000      49.800000    0.820462    0.749000    0.596476
#
# [8 rows x 28 columns]

# %%
df["prod_var"].max()
# Out:
# 0.5964759075907591

# %%
df["prod_var"].min()
# Out:
# 0.0

# %%
uk_consts = gpd.read_file("uk_consts.geojson")

# %%
uk_consts = uk_consts.sort_values(by='PCON21NM')

uk_consts
# Out:
#      OBJECTID   PCON21CD                   PCON21NM   BNG_E   BNG_N     LONG  \
# 618       619  W07000049                   Aberavon  281995  189115 -3.70476
# 627       628  W07000058                  Aberconwy  276098  360879 -3.85333
# 551       552  S14000001             Aberdeen North  389796  808947 -2.17038
# 552       553  S14000002             Aberdeen South  384014  802600 -2.26559
# 553       554  S14000003         Airdrie and Shotts  283330  662650 -3.86475
# ..        ...        ...                        ...     ...     ...      ...
# 529       530  E14001059  Wythenshawe and Sale East  380730  389917 -2.29132
# 530       531  E14001060                     Yeovil  340522  114840 -2.84771
# 610       611  W07000041                   Ynys Mon  245217  378331 -4.32298
# 531       532  E14001061               York Central  459887  451276 -1.08890
# 532       533  E14001062                 York Outer  461058  457909 -1.06973
#
#           LAT                              GlobalID  \
# 618  51.58849  19512a3e-da10-40aa-8b58-63c4d95ebddc
# 627  53.13064  905b3135-3985-442f-9d4d-94289f069daa
# 551  57.17123  d7aaa252-2998-4395-a5f8-1d1ddb181ca9
# 552  57.11405  ec5c9e47-032a-4498-9cc2-9acbb07b24ba
# 553  55.84290  a782a886-3175-4124-9338-7aa87fa46a3f
# ..        ...                                   ...
# 529  53.40573  844ba253-84d6-4666-86ed-ede3c807e045
# 530  50.92992  e9efc171-7d47-45ab-b528-a44898f02899
# 610  53.27931  05d45682-3ad5-4665-91ec-f3ec0ebc0479
# 531  53.95413  0b4d7d08-bcde-43fc-8b4c-a662506a6009
# 532  54.01360  23fcd766-8e52-4305-b8eb-060c4155abe9
#
#                                               geometry
# 618  MULTIPOLYGON (((272080.903 198199.495, 272120....
# 627  MULTIPOLYGON (((277675.810 368265.290, 277663....
# 551  MULTIPOLYGON (((393806.950 809630.000, 393801....
# 552  MULTIPOLYGON (((396494.604 802552.201, 396491....
# 553  POLYGON ((290853.901 662155.299, 290854.198 66...
# ..                                                 ...
# 529  POLYGON ((380187.802 393434.200, 380181.000 39...
# 530  POLYGON ((355919.100 126776.700, 355912.999 12...
# 610  MULTIPOLYGON (((239052.158 363430.995, 239058....
# 531  POLYGON ((459954.704 454309.005, 460000.002 45...
# 532  POLYGON ((470559.798 455585.100, 470574.697 45...
#
# [650 rows x 9 columns]

# %%
df = df.sort_values(by='Constituency')

df
# Out:
#                   Constituency                    Region      Con      Lab  \
# 0                     Aberavon                     Wales   3742.0  15416.0
# 1                    Aberconwy                     Wales  12513.0   8514.0
# 2               Aberdeen North                  Scotland   5304.0  11397.0
# 3               Aberdeen South                  Scotland  11087.0  12991.0
# 4           Airdrie and Shotts                  Scotland   3389.0  15108.0
# ..                         ...                       ...      ...      ...
# 645  Wythenshawe and Sale East        North West England  11124.0  21693.0
# 646                     Yeovil        South West England  24178.0   4053.0
# 647                   Ynys Mon                     Wales   7393.0  10871.0
# 648               York Central  Yorkshire and the Humber  13496.0  20212.0
# 649                 York Outer  Yorkshire and the Humber  26477.0  13348.0
#
#        UKIP       LD      SNP     Grn  DUP       PC  ...  Majority  \
# 0    4971.0   1397.0      0.0   711.0  0.0   3663.0  ...     10445
# 1    3467.0   1391.0      0.0   727.0  0.0   3536.0  ...      3999
# 2       0.0   2050.0  24793.0     0.0  0.0      0.0  ...     13396
# 3     897.0   2252.0  20221.0   964.0  0.0      0.0  ...      7230
# 4    1088.0    678.0  23887.0     0.0  0.0      0.0  ...      8779
# ..      ...      ...      ...     ...  ...      ...  ...       ...
# 645  6354.0   1927.0      0.0  1658.0  0.0      0.0  ...     10569
# 646  7646.0  18865.0      0.0  2191.0  0.0      0.0  ...      5313
# 647  5121.0    751.0      0.0     0.0  0.0  10642.0  ...       229
# 648  4795.0   3804.0      0.0  4791.0  0.0      0.0  ...      6716
# 649  5251.0   6269.0      0.0  2558.0  0.0      0.0  ...     13129
#
#      MajorityPct  TurnoutPct2015  RemainPct  LeavePct  LeaveMajority  \
# 0          33.13            63.3       40.1      59.9           19.8
# 1          13.26            66.2       46.7      53.3            6.6
# 2          30.49            64.9       57.0      43.0          -14.0
# 3          14.89            71.3       67.7      32.3          -35.4
# 4          19.82            66.4       60.0      40.0          -20.0
# ..           ...             ...        ...       ...            ...
# 645        24.43            56.9       50.2      49.8           -0.4
# 646         9.33            69.1       40.8      59.2           18.4
# 647         0.66            69.9       49.1      50.9            1.8
# 648        14.09            63.3       61.5      38.5          -23.0
# 649        24.36            68.6       55.1      44.9          -10.2
#
#       2017_winner  con_ratio leave_prop  prod_var
# 0          Labour   0.276401      0.599  0.165564
# 1    Conservative   0.530052      0.533  0.282518
# 2             SNP   0.120721      0.430  0.051910
# 3    Conservative   0.246833      0.323  0.079727
# 4             SNP   0.101093      0.400  0.040437
# ..            ...        ...        ...       ...
# 645        Labour   0.403994      0.498  0.201189
# 646  Conservative   0.558973      0.592  0.330912
# 647        Labour   0.358300      0.509  0.182375
# 648        Labour   0.383644      0.385  0.147703
# 649  Conservative   0.588613      0.449  0.264287
#
# [650 rows x 33 columns]

# %%
merge_df = uk_consts.merge(df, how="left", left_on="PCON21NM", right_on="Constituency")

# %%
merge_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 650 entries, 0 to 649
# Data columns (total 42 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBJECTID          650 non-null    int64
#  1   PCON21CD          650 non-null    object
#  2   PCON21NM          650 non-null    object
#  3   BNG_E             650 non-null    int64
#  4   BNG_N             650 non-null    int64
#  5   LONG              650 non-null    float64
#  6   LAT               650 non-null    float64
#  7   GlobalID          650 non-null    object
#  8   geometry          650 non-null    geometry
#  9   Constituency      650 non-null    object
#  10  Region            650 non-null    object
#  11  Con               650 non-null    float64
#  12  Lab               650 non-null    float64
#  13  UKIP              650 non-null    float64
#  14  LD                650 non-null    float64
#  15  SNP               650 non-null    float64
#  16  Grn               650 non-null    float64
#  17  DUP               650 non-null    float64
#  18  PC                650 non-null    float64
#  19  SF                650 non-null    float64
#  20  UUP               650 non-null    float64
#  21  SDLP              650 non-null    float64
#  22  Alliance          650 non-null    float64
#  23  Ind               650 non-null    float64
#  24  Spk               650 non-null    float64
#  25  Others            650 non-null    float64
#  26  ValidVotes        650 non-null    int64
#  27  WinningParty      650 non-null    object
#  28  SecondPlace       650 non-null    object
#  29  WinningVotes      650 non-null    int64
#  30  SecondPlaceVotes  650 non-null    int64
#  31  WinningPct        650 non-null    float64
#  32  Majority          650 non-null    int64
#  33  MajorityPct       650 non-null    float64
#  34  TurnoutPct2015    650 non-null    float64
#  35  RemainPct         650 non-null    float64
#  36  LeavePct          650 non-null    float64
#  37  LeaveMajority     650 non-null    float64
#  38  2017_winner       650 non-null    object
#  39  con_ratio         650 non-null    float64
#  40  leave_prop        650 non-null    float64
#  41  prod_var          650 non-null    float64
# dtypes: float64(26), geometry(1), int64(7), object(8)
# memory usage: 218.4+ KB

# %%
merge_df
# Out:
#      OBJECTID   PCON21CD                   PCON21NM   BNG_E   BNG_N     LONG  \
# 0         619  W07000049                   Aberavon  281995  189115 -3.70476
# 1         628  W07000058                  Aberconwy  276098  360879 -3.85333
# 2         552  S14000001             Aberdeen North  389796  808947 -2.17038
# 3         553  S14000002             Aberdeen South  384014  802600 -2.26559
# 4         554  S14000003         Airdrie and Shotts  283330  662650 -3.86475
# ..        ...        ...                        ...     ...     ...      ...
# 645       530  E14001059  Wythenshawe and Sale East  380730  389917 -2.29132
# 646       531  E14001060                     Yeovil  340522  114840 -2.84771
# 647       611  W07000041                   Ynys Mon  245217  378331 -4.32298
# 648       532  E14001061               York Central  459887  451276 -1.08890
# 649       533  E14001062                 York Outer  461058  457909 -1.06973
#
#           LAT                              GlobalID  \
# 0    51.58849  19512a3e-da10-40aa-8b58-63c4d95ebddc
# 1    53.13064  905b3135-3985-442f-9d4d-94289f069daa
# 2    57.17123  d7aaa252-2998-4395-a5f8-1d1ddb181ca9
# 3    57.11405  ec5c9e47-032a-4498-9cc2-9acbb07b24ba
# 4    55.84290  a782a886-3175-4124-9338-7aa87fa46a3f
# ..        ...                                   ...
# 645  53.40573  844ba253-84d6-4666-86ed-ede3c807e045
# 646  50.92992  e9efc171-7d47-45ab-b528-a44898f02899
# 647  53.27931  05d45682-3ad5-4665-91ec-f3ec0ebc0479
# 648  53.95413  0b4d7d08-bcde-43fc-8b4c-a662506a6009
# 649  54.01360  23fcd766-8e52-4305-b8eb-060c4155abe9
#
#                                               geometry  \
# 0    MULTIPOLYGON (((272080.903 198199.495, 272120....
# 1    MULTIPOLYGON (((277675.810 368265.290, 277663....
# 2    MULTIPOLYGON (((393806.950 809630.000, 393801....
# 3    MULTIPOLYGON (((396494.604 802552.201, 396491....
# 4    POLYGON ((290853.901 662155.299, 290854.198 66...
# ..                                                 ...
# 645  POLYGON ((380187.802 393434.200, 380181.000 39...
# 646  POLYGON ((355919.100 126776.700, 355912.999 12...
# 647  MULTIPOLYGON (((239052.158 363430.995, 239058....
# 648  POLYGON ((459954.704 454309.005, 460000.002 45...
# 649  POLYGON ((470559.798 455585.100, 470574.697 45...
#
#                   Constituency  ... Majority  MajorityPct  TurnoutPct2015  \
# 0                     Aberavon  ...    10445        33.13            63.3
# 1                    Aberconwy  ...     3999        13.26            66.2
# 2               Aberdeen North  ...    13396        30.49            64.9
# 3               Aberdeen South  ...     7230        14.89            71.3
# 4           Airdrie and Shotts  ...     8779        19.82            66.4
# ..                         ...  ...      ...          ...             ...
# 645  Wythenshawe and Sale East  ...    10569        24.43            56.9
# 646                     Yeovil  ...     5313         9.33            69.1
# 647                   Ynys Mon  ...      229         0.66            69.9
# 648               York Central  ...     6716        14.09            63.3
# 649                 York Outer  ...    13129        24.36            68.6
#
#      RemainPct  LeavePct  LeaveMajority   2017_winner  con_ratio  leave_prop  \
# 0         40.1      59.9           19.8        Labour   0.276401       0.599
# 1         46.7      53.3            6.6  Conservative   0.530052       0.533
# 2         57.0      43.0          -14.0           SNP   0.120721       0.430
# 3         67.7      32.3          -35.4  Conservative   0.246833       0.323
# 4         60.0      40.0          -20.0           SNP   0.101093       0.400
# ..         ...       ...            ...           ...        ...         ...
# 645       50.2      49.8           -0.4        Labour   0.403994       0.498
# 646       40.8      59.2           18.4  Conservative   0.558973       0.592
# 647       49.1      50.9            1.8        Labour   0.358300       0.509
# 648       61.5      38.5          -23.0        Labour   0.383644       0.385
# 649       55.1      44.9          -10.2  Conservative   0.588613       0.449
#
#      prod_var
# 0    0.165564
# 1    0.282518
# 2    0.051910
# 3    0.079727
# 4    0.040437
# ..        ...
# 645  0.201189
# 646  0.330912
# 647  0.182375
# 648  0.147703
# 649  0.264287
#
# [650 rows x 42 columns]

# %%
merge_df.iloc[139]
# Out:
# OBJECTID                                                          111
# PCON21CD                                                    E14000640
# PCON21NM                                              City of Chester
# BNG_E                                                          339232
# BNG_N                                                          361928
# LONG                                                          -2.9101
# LAT                                                          53.15102
# GlobalID                         3f7d5cc5-e395-4813-a7b3-c5c6149e250d
# geometry            POLYGON ((346137.7037 369314.404200001, 346134...
# Constituency                                          City of Chester
# Region                                             North West England
# Con                                                           22025.0
# Lab                                                           22118.0
# UKIP                                                           4148.0
# LD                                                             2870.0
# SNP                                                               0.0
# Grn                                                               0.0
# DUP                                                               0.0
# PC                                                                0.0
# SF                                                                0.0
# UUP                                                               0.0
# SDLP                                                              0.0
# Alliance                                                          0.0
# Ind                                                               0.0
# Spk                                                               0.0
# Others                                                            0.0
# ValidVotes                                                      51161
# WinningParty                                                   Labour
# SecondPlace                                              Conservative
# WinningVotes                                                    22118
# SecondPlaceVotes                                                22025
# WinningPct                                                      43.23
# Majority                                                           93
# MajorityPct                                                      0.18
# TurnoutPct2015                                                    0.0
# RemainPct                                                        57.3
# LeavePct                                                         42.7
# LeaveMajority                                                   -14.6
# 2017_winner                                                    Labour
# con_ratio                                                    0.511581
# leave_prop                                                      0.427
# prod_var                                                     0.218445
# Name: 139, dtype: object

# %%
"""for a,b  in list(zip(uk_consts["PCON21NM"], df["Constituency"])):
    
    if a != b:
        print("ISSUE:")
    print(a, "||", b)
    print("\n")"""
# Out:
# 'for a,b  in list(zip(uk_consts["PCON21NM"], df["Constituency"])):\n    \n    if a != b:\n        print("ISSUE:")\n    print(a, "||", b)\n    print("\n")'

# %%
merge_df.plot(column="leave_prop", cmap="viridis", linewidth=0.1, edgecolor='0.9', legend=True)
plt.xticks([])
plt.yticks([])
plt.title("Choropleth showing the proportion of Leave voters in the 2016 UK referendum on EU membership")
plt.grid()
#plt.savefig('leave_voting.jpg', format='jpg', dpi=400, bbox_inches='tight')
plt.show()

# %%
merge_df.plot(column="con_ratio", cmap="cividis", linewidth=0.1, edgecolor='0.9', legend=True)
merge_df[merge_df["Constituency"] == "Buckingham"].plot(color="white", linewidth=0.5, edgecolor='k', ax=plt.gca())
plt.xticks([])
plt.yticks([])
plt.title("Choropleth showing the proportion of Tory or UKIP voters in the UK 2017 General Election")
plt.grid()
#plt.savefig('conservative_ukip_support.jpg', format='jpg', dpi=400, bbox_inches='tight')
plt.show()

# %%
merge_df = merge_df.drop(columns="prod_var")

# %%
merge_df["con_normed"] = (merge_df["con_ratio"] - merge_df["con_ratio"].min()) / (merge_df["con_ratio"].max() - merge_df["con_ratio"].min())

# %%
merge_df["leave_normed"] = (merge_df["leave_prop"] - merge_df["leave_prop"].min()) / (merge_df["leave_prop"].max() - merge_df["leave_prop"].min())

# %%
merge_df["leave_prop"].max()
# Out:
# 0.7490000000000001

# %%
merge_df["leave_prop"].min()
# Out:
# 0.205

# %%
merge_df["leave_normed"].max()
# Out:
# 1.0

# %%
merge_df["leave_normed"].min()
# Out:
# 0.0

# %%
merge_df["bin_vals"] = [1 if _ <= 0.5 else 0 for _ in merge_df["leave_prop"]]

# %%
merge_df.plot(column="bin_vals", cmap="viridis", linewidth=0.5, edgecolor='r', legend=False)

colors = ['#ffe44c', '#480454']
labels = ['Remain', 'Leave']

legend_patches = [Patch(color=color, label=label) for color, label in zip(colors, labels)]

plt.legend(handles=legend_patches, fontsize=24)
plt.xticks([])
plt.yticks([])
plt.title("Majority Leave vs Majority Remain Support in 2016 UK referendum on EU membership")
plt.grid()
#plt.savefig('majority_support.jpg', format='jpg', dpi=400, bbox_inches='tight')
plt.show()

# %%
l25 = merge_df["leave_normed"].quantile(0.25)

merge_df["leave_normed"].quantile(0.25)
# Out:
# 0.4531249999999999

# %%
l50 = merge_df["leave_normed"].quantile(0.50)

merge_df["leave_normed"].quantile(0.50)
# Out:
# 0.6084558823529411

# %%
l75 = merge_df["leave_normed"].quantile(0.75)

merge_df["leave_normed"].quantile(0.75)
# Out:
# 0.725643382352941

# %%
c25 = merge_df["con_normed"].quantile(0.25)

merge_df["con_normed"].quantile(0.25)
# Out:
# 0.42353947156195987

# %%
c50 = merge_df["con_normed"].quantile(0.5)

merge_df["con_normed"].quantile(0.5)
# Out:
# 0.6335386343673619

# %%
c75 = merge_df["con_normed"].quantile(0.75)

merge_df["con_normed"].quantile(0.75)
# Out:
# 0.8020680415873206

# %%
def quartiles(x, low, mid, high):
    output = None
    if x < mid:
        if x < low:
            output=1
        else:
            output=2
    else:
        if x < high:
            output=3
        else:
            output=4
    return output

# %%
merge_df["leave_qs"] = merge_df["leave_normed"].apply(lambda x: quartiles(x, low=l25, mid=l50, high=l75))

# %%
merge_df["con_qs"] = merge_df["con_normed"].apply(lambda x: quartiles(x, low=c25, mid=c50, high=c75))

# %%
#(row, column)


# 4,1 = #78ccd4
# 4,2 = #70acc4
# 4,3 = #6884b4
# 4,4 = #6064a4

# 3,1 = #a0dcdc
# 3,2 = #98b4cc
# 3,3 = #908cbc
# 3,4 = #806cac

# 2,1 = #c8e4e4
# 2,2 = #b8bcd4
# 2,3 = #b09cc4
# 2,4 = #a874b4

# 1,1 = #f0ecec
# 1,2 = #e0c4dc
# 1,3 = #d89ccc
# 1,4 = #d07cbc

col_dict = {(4,1): "#78ccd4", (4,2): "#70acc4", (4,3): "#6884b4", (4,4): "#6064a4", 
           (3,1): "#a0dcdc", (3,2): "#98b4cc", (3,3): "#908cbc", (3,4): "#806cac",
           (2,1): "#c8e4e4", (2,2): "#b8bcd4", (2,3): "#b09cc4", (2,4): "#a874b4",
           (1,1): "#f0ecec", (1,2): "#e0c4dc", (1,3): "#d89ccc", (1,4): "#d07cbc"}

# %%
merge_df
# Out:
#      OBJECTID   PCON21CD                   PCON21NM   BNG_E   BNG_N     LONG  \
# 0         619  W07000049                   Aberavon  281995  189115 -3.70476
# 1         628  W07000058                  Aberconwy  276098  360879 -3.85333
# 2         552  S14000001             Aberdeen North  389796  808947 -2.17038
# 3         553  S14000002             Aberdeen South  384014  802600 -2.26559
# 4         554  S14000003         Airdrie and Shotts  283330  662650 -3.86475
# ..        ...        ...                        ...     ...     ...      ...
# 645       530  E14001059  Wythenshawe and Sale East  380730  389917 -2.29132
# 646       531  E14001060                     Yeovil  340522  114840 -2.84771
# 647       611  W07000041                   Ynys Mon  245217  378331 -4.32298
# 648       532  E14001061               York Central  459887  451276 -1.08890
# 649       533  E14001062                 York Outer  461058  457909 -1.06973
#
#           LAT                              GlobalID  \
# 0    51.58849  19512a3e-da10-40aa-8b58-63c4d95ebddc
# 1    53.13064  905b3135-3985-442f-9d4d-94289f069daa
# 2    57.17123  d7aaa252-2998-4395-a5f8-1d1ddb181ca9
# 3    57.11405  ec5c9e47-032a-4498-9cc2-9acbb07b24ba
# 4    55.84290  a782a886-3175-4124-9338-7aa87fa46a3f
# ..        ...                                   ...
# 645  53.40573  844ba253-84d6-4666-86ed-ede3c807e045
# 646  50.92992  e9efc171-7d47-45ab-b528-a44898f02899
# 647  53.27931  05d45682-3ad5-4665-91ec-f3ec0ebc0479
# 648  53.95413  0b4d7d08-bcde-43fc-8b4c-a662506a6009
# 649  54.01360  23fcd766-8e52-4305-b8eb-060c4155abe9
#
#                                               geometry  \
# 0    MULTIPOLYGON (((272080.903 198199.495, 272120....
# 1    MULTIPOLYGON (((277675.810 368265.290, 277663....
# 2    MULTIPOLYGON (((393806.950 809630.000, 393801....
# 3    MULTIPOLYGON (((396494.604 802552.201, 396491....
# 4    POLYGON ((290853.901 662155.299, 290854.198 66...
# ..                                                 ...
# 645  POLYGON ((380187.802 393434.200, 380181.000 39...
# 646  POLYGON ((355919.100 126776.700, 355912.999 12...
# 647  MULTIPOLYGON (((239052.158 363430.995, 239058....
# 648  POLYGON ((459954.704 454309.005, 460000.002 45...
# 649  POLYGON ((470559.798 455585.100, 470574.697 45...
#
#                   Constituency  ... LeavePct  LeaveMajority   2017_winner  \
# 0                     Aberavon  ...     59.9           19.8        Labour
# 1                    Aberconwy  ...     53.3            6.6  Conservative
# 2               Aberdeen North  ...     43.0          -14.0           SNP
# 3               Aberdeen South  ...     32.3          -35.4  Conservative
# 4           Airdrie and Shotts  ...     40.0          -20.0           SNP
# ..                         ...  ...      ...            ...           ...
# 645  Wythenshawe and Sale East  ...     49.8           -0.4        Labour
# 646                     Yeovil  ...     59.2           18.4  Conservative
# 647                   Ynys Mon  ...     50.9            1.8        Labour
# 648               York Central  ...     38.5          -23.0        Labour
# 649                 York Outer  ...     44.9          -10.2  Conservative
#
#      con_ratio  leave_prop  con_normed  leave_normed  bin_vals  leave_qs  \
# 0     0.276401       0.599    0.336885      0.724265         0         3
# 1     0.530052       0.533    0.646041      0.602941         0         2
# 2     0.120721       0.430    0.147138      0.413603         1         1
# 3     0.246833       0.323    0.300847      0.216912         1         1
# 4     0.101093       0.400    0.123215      0.358456         1         1
# ..         ...         ...         ...           ...       ...       ...
# 645   0.403994       0.498    0.492398      0.538603         1         2
# 646   0.558973       0.592    0.681290      0.711397         0         3
# 647   0.358300       0.509    0.436706      0.558824         0         2
# 648   0.383644       0.385    0.467595      0.330882         1         1
# 649   0.588613       0.449    0.717416      0.448529         1         1
#
#      con_qs
# 0         1
# 1         3
# 2         1
# 3         1
# 4         1
# ..      ...
# 645       2
# 646       3
# 647       2
# 648       2
# 649       3
#
# [650 rows x 46 columns]

# %%
legend_patches = []
color_order = []

for con in range(1,5):
    for leave in range(1,5)[::-1]:
        
        merge_df[(merge_df["leave_qs"] == leave) & (merge_df["con_qs"] == con)].plot(color=col_dict[(leave, con)], linewidth=0.5, edgecolor='k', ax=plt.gca())
        legend_patches.append(Patch(color=col_dict[(leave, con)]))
        color_order.append(col_dict[(leave, con)])
        
merge_df[merge_df["Constituency"] == "Buckingham"].plot(color="k", linewidth=0.5, edgecolor='k', ax=plt.gca())
        
#plt.legend(handles=legend_patches, loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=4, frameon=False, handlelength=1, handleheight=1)

plt.xticks([])
plt.yticks([])
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(8,8))


ax.set_aspect('equal', adjustable='box')

for con in range(1,5):
    for leave in range(1,5)[::-1]:
        
        pc = PatchCollection([Rectangle((con-1,leave-1),1,1)], facecolor=col_dict[(leave, con)] )
        ax.add_collection(pc)
        
ax.set_xlim([0,4])
ax.set_ylim([0,4])
ax.set_xticks([0, 1, 2, 3, 4], [0, 25, 50, 75, 100], fontsize=20)
ax.set_yticks([0, 1, 2, 3, 4], [0, 25, 50, 75, 100], fontsize=20)
plt.xlabel("Quartile of Tory or UKIP support 2017", fontsize=20)
plt.ylabel("Quartile of Leave support 2016", fontsize=20)
ax.grid(linewidth=0)
ax.plot()
plt.show()

# %%
sns.set_style("whitegrid")

# %%
legend_patches = []
color_order = []

for con in range(1,5):
    for leave in range(1,5)[::-1]:

        
        merge_df[(merge_df["leave_qs"] == leave) & (merge_df["con_qs"] == con)].plot(color=col_dict[(leave, con)], linewidth=0.5, edgecolor='k', ax=plt.gca())
        legend_patches.append(Patch(color=col_dict[(leave, con)]))
        color_order.append(col_dict[(leave, con)])
        
merge_df[merge_df["Constituency"] == "Buckingham"].plot(color="k", linewidth=0.5, edgecolor='k', ax=plt.gca())
        
#plt.legend(handles=legend_patches, loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=4, frameon=False, handlelength=1, handleheight=1)

ax.figure.canvas.draw()

rbga_buff = np.asarray(ax.figure.canvas.renderer.buffer_rgba())

img = Image.fromarray(rbga_buff)
img = img.resize((400,400))


plt.figimage(img, xo=20, yo=1450, origin='upper')
plt.title("Bivariate Choropleth comparing Leave Support (2016) and Conservative/UKIP voter support (2017)")
plt.xticks([])
plt.yticks([])
plt.grid()
#plt.savefig('bivariate_choropleth.jpg', format='jpg')
plt.show()
